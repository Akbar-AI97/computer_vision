# %% [markdown]
# <a href="https://colab.research.google.com/github/Akbar-AI97/computer_vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download("uzbek pilaf plov food",
                    limit=100,
                    output_dir="/content/pilaf_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://wimg.rule34.xxx/images/912/2859cabf217b694f1f845d1397ac172b.png?17190624
# [%] File Downloaded!
#
#
#
# [!!] Indexing page: 2
#
# [%] Indexed 1 Images on Page 2.
#
# ...
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/b1/77/5e/b1775edec18f8ae3316b53751e70285c.jpg
# [%] File Downloaded!
#
#
#
# [!!] Indexing page: 3
#
# [%] Indexed 1 Images on Page 3.
#
# ...
#
# [%] Downloading Image #3 from https://jconlineimagem.ne10.uol.com.br/imagem/noticia/2020/01/17/normal/e3431114e8636761d32c796f91ceac88.jpg
# [%] File Downloaded!
#
#
#
# [!!] Indexing page: 4
#
# [%] Indexed 1 Images on Page 4.
#
# ...
#
# [%] Downloading Image #4 from https://www.247games.com/pix/solitaire-247-thumb.png
# [%] File Downloaded!
#
#
#
# [!!] Indexing page: 5
#
# [%] Indexed 12 Images on Page 5.
#
# ...
#
# ...

# %%
# !rm -rf /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil

sourcec_dir = '/content/pilaf_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(sourcec_dir):
  src_file = os.path.join(sourcec_dir, filename)
  dst_file = os.path.join(target_dir, filename)
  shutil.copy(src_file, dst_file)

# %%
downloader.download("kebab shashlik food",
                    limit=100,
                    output_dir="/content/kebab_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.licious.in/blog/wp-content/uploads/2020/12/Turkish-Kebabs-min.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://wallpaperaccess.com/full/10831705.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/f9/4d/9b/f94d9bc8f56d3d0302fc7e727947eb0d.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://www.thespruceeats.com/thmb/47Y9vapBkwe_98TIiueYFB3OObc=/2059x2059/filters:no_upscale():max_bytes(150000):strip_icc()/aIMG_0756fsq-5aebd1ddc0647100364ee63a.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://img.freepik.com/premium-photo/doner-kebab-doner-kebap-fast-food-meal-flatbread-with-fries-wooden-board_770123-5.jpg?w=2000
# [%] File Downloaded!
#
# ...

# %%
import os, shutil

sourcec_dir = '/content/kebab_images/kebab shashlik food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(sourcec_dir):
  src_file = os.path.join(sourcec_dir, filename)
  dst_file = os.path.join(target_dir, filename)
  shutil.copy(src_file, dst_file)
